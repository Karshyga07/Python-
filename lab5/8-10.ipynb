# %%
import re
with open("row.txt", 'r', encoding = "utf-8") as f:
    data = f.read()
print("task 9")
pettern = r'[А-Я][^а-я]*'
for match in data.split('\n'):
    matches = re.findall(pettern, match)
    if matches:
        print(f'{match} = {matches}')
# Out:
# task 9
# ДУБЛИКАТ  = ['ДУБЛИКАТ ']
# Филиал ТОО EUROPHARMA Астана = ['Ф', 'ТОО EUROPHARMA А']
# БИН 080841000761 = ['БИН 080841000761']
# НДС Серия 58001 = ['НДС С']
# Касса 300-189 = ['К']
# Смена 10 = ['С']
# Порядковый номер чека №64 = ['П']
# Чек №2331180266 = ['Ч']
# Кассир Аптека 17-1 = ['К', 'А']
# ПРОДАЖА = ['ПРОДАЖА']
# Натрия хлорид 0,9%, 200 мл, фл = ['Н']
# Стоимость = ['С']
# Борный спирт 3%, 20 мл, фл. = ['Б']
# Стоимость = ['С']
# Шприц 2 мл, 3-х комп. (Bioject) = ['Ш']
# Стоимость = ['С']
# Система для инфузии Vogt Medical = ['С']
# Стоимость = ['С']
# Naturella прокладки Классик макси №8 = ['К']
# Стоимость = ['С']
# AURA Ватные диски №150 = ['В']
# Стоимость = ['С']
# Чистая линия скраб мягкий 50 мл = ['Ч']
# Стоимость = ['С']
# Чистая линия  скраб очищающийабрикос 50 мл = ['Ч']
# Стоимость = ['С']
# Чистая линия скраб мягкий 50 мл = ['Ч']
# Стоимость = ['С']
# Carefree салфетки Алоэвоздухопроницаемые №20 = ['А']
# Стоимость = ['С']
# Pro Series Шампунь яркий цвет 500мл = ['Ш']
# Стоимость = ['С']
# Pro Series бальзам-ополаскивательдля длител ухода за окрашеннымиволосами Яркий цвет 500мл = ['Я']
# Стоимость = ['С']
# Clear шампунь Актив спорт 2в1мужской  400 мл = ['А']
# Стоимость = ['С']
# Bio World (HYDRO THERAPY)Мицеллярная вода 5в1, 445мл = ['М']
# Стоимость = ['С']
# Bio World (HYDRO THERAPY) Гель-муссдля умывания с гиалуроновойкислотой, 250мл = ['Г']
# Стоимость = ['С']
# [RX]-Натрия хлорид 0,9%, 100 мл, фл. = ['Н']
# Стоимость = ['С']
# [RX]-Дисоль р-р 400 мл, фл. = ['Д']
# Стоимость = ['С']
# Тагансорбент с иономи серебра №30,пор. = ['Т']
# Стоимость = ['С']
# [RX]-Церукал 2%, 2 мл, №10, амп. = ['Ц']
# Стоимость = ['С']
# [RX]-Андазол 200 мг, №40, табл. = ['А']
# Стоимость = ['С']
# Банковская карта: = ['Б']
# ИТОГО: = ['ИТОГО:']
# в т.ч. НДС 12%: = ['НДС 12%:']
# Фискальный признак: = ['Ф']
# Время: 18.04.2019 11:13:58 = ['В']
# г. Нур-султан,Казахстан, Мангилик Ел,19, нп-5 = ['Н', 'К', 'М', 'Е']
# Оператор фискальных данных: АО"Казахтелеком"Для проверки чека зайдите на сайт:consumer.oofd.kz = ['О', 'АО"К', 'Д']
# ФИСКАЛЬНЫЙ ЧЕК = ['ФИСКАЛЬНЫЙ ЧЕК']
# ФП = ['ФП']
# ИНК ОФД: 311559 = ['ИНК ОФД: 311559']
# Код ККМ КГД (РНМ): 620300145316 = ['К', 'ККМ КГД (РНМ): 620300145316']
# ЗНМ: SWK00034961 = ['ЗНМ: SWK00034961']

# %%
import re
with open("row.txt", 'r', encoding = "utf-8") as f:
    data = f.read()
print("task 8")
patteron = r'[А-Я][^А-Я]*'
for match in data.split('\n'):
    matches = re.findall(patteron, match)
    if matches:
        print(f'{match} = {matches}')
# Out:
# task 8
# ДУБЛИКАТ  = ['Д', 'У', 'Б', 'Л', 'И', 'К', 'А', 'Т ']
# Филиал ТОО EUROPHARMA Астана = ['Филиал ', 'Т', 'О', 'О EUROPHARMA ', 'Астана']
# БИН 080841000761 = ['Б', 'И', 'Н 080841000761']
# НДС Серия 58001 = ['Н', 'Д', 'С ', 'Серия 58001']
# Касса 300-189 = ['Касса 300-189']
# Смена 10 = ['Смена 10']
# Порядковый номер чека №64 = ['Порядковый номер чека №64']
# Чек №2331180266 = ['Чек №2331180266']
# Кассир Аптека 17-1 = ['Кассир ', 'Аптека 17-1']
# ПРОДАЖА = ['П', 'Р', 'О', 'Д', 'А', 'Ж', 'А']
# Натрия хлорид 0,9%, 200 мл, фл = ['Натрия хлорид 0,9%, 200 мл, фл']
# Стоимость = ['Стоимость']
# Борный спирт 3%, 20 мл, фл. = ['Борный спирт 3%, 20 мл, фл.']
# Стоимость = ['Стоимость']
# Шприц 2 мл, 3-х комп. (Bioject) = ['Шприц 2 мл, 3-х комп. (Bioject)']
# Стоимость = ['Стоимость']
# Система для инфузии Vogt Medical = ['Система для инфузии Vogt Medical']
# Стоимость = ['Стоимость']
# Naturella прокладки Классик макси №8 = ['Классик макси №8']
# Стоимость = ['Стоимость']
# AURA Ватные диски №150 = ['Ватные диски №150']
# Стоимость = ['Стоимость']
# Чистая линия скраб мягкий 50 мл = ['Чистая линия скраб мягкий 50 мл']
# Стоимость = ['Стоимость']
# Чистая линия  скраб очищающийабрикос 50 мл = ['Чистая линия  скраб очищающийабрикос 50 мл']
# Стоимость = ['Стоимость']
# Чистая линия скраб мягкий 50 мл = ['Чистая линия скраб мягкий 50 мл']
# Стоимость = ['Стоимость']
# Carefree салфетки Алоэвоздухопроницаемые №20 = ['Алоэвоздухопроницаемые №20']
# Стоимость = ['Стоимость']
# Pro Series Шампунь яркий цвет 500мл = ['Шампунь яркий цвет 500мл']
# Стоимость = ['Стоимость']
# Pro Series бальзам-ополаскивательдля длител ухода за окрашеннымиволосами Яркий цвет 500мл = ['Яркий цвет 500мл']
# Стоимость = ['Стоимость']
# Clear шампунь Актив спорт 2в1мужской  400 мл = ['Актив спорт 2в1мужской  400 мл']
# Стоимость = ['Стоимость']
# Bio World (HYDRO THERAPY)Мицеллярная вода 5в1, 445мл = ['Мицеллярная вода 5в1, 445мл']
# Стоимость = ['Стоимость']
# Bio World (HYDRO THERAPY) Гель-муссдля умывания с гиалуроновойкислотой, 250мл = ['Гель-муссдля умывания с гиалуроновойкислотой, 250мл']
# Стоимость = ['Стоимость']
# [RX]-Натрия хлорид 0,9%, 100 мл, фл. = ['Натрия хлорид 0,9%, 100 мл, фл.']
# Стоимость = ['Стоимость']
# [RX]-Дисоль р-р 400 мл, фл. = ['Дисоль р-р 400 мл, фл.']
# Стоимость = ['Стоимость']
# Тагансорбент с иономи серебра №30,пор. = ['Тагансорбент с иономи серебра №30,пор.']
# Стоимость = ['Стоимость']
# [RX]-Церукал 2%, 2 мл, №10, амп. = ['Церукал 2%, 2 мл, №10, амп.']
# Стоимость = ['Стоимость']
# [RX]-Андазол 200 мг, №40, табл. = ['Андазол 200 мг, №40, табл.']
# Стоимость = ['Стоимость']
# Банковская карта: = ['Банковская карта:']
# ИТОГО: = ['И', 'Т', 'О', 'Г', 'О:']
# в т.ч. НДС 12%: = ['Н', 'Д', 'С 12%:']
# Фискальный признак: = ['Фискальный признак:']
# Время: 18.04.2019 11:13:58 = ['Время: 18.04.2019 11:13:58']
# г. Нур-султан,Казахстан, Мангилик Ел,19, нп-5 = ['Нур-султан,', 'Казахстан, ', 'Мангилик ', 'Ел,19, нп-5']
# Оператор фискальных данных: АО"Казахтелеком"Для проверки чека зайдите на сайт:consumer.oofd.kz = ['Оператор фискальных данных: ', 'А', 'О"', 'Казахтелеком"', 'Для проверки чека зайдите на сайт:consumer.oofd.kz']
# ФИСКАЛЬНЫЙ ЧЕК = ['Ф', 'И', 'С', 'К', 'А', 'Л', 'Ь', 'Н', 'Ы', 'Й ', 'Ч', 'Е', 'К']
# ФП = ['Ф', 'П']
# ИНК ОФД: 311559 = ['И', 'Н', 'К ', 'О', 'Ф', 'Д: 311559']
# Код ККМ КГД (РНМ): 620300145316 = ['Код ', 'К', 'К', 'М ', 'К', 'Г', 'Д (', 'Р', 'Н', 'М): 620300145316']
# ЗНМ: SWK00034961 = ['З', 'Н', 'М: SWK00034961']

# %%
import re 
with open("row.txt", 'r', encoding = "utf-8") as f:
    data = f.read()
print("task 10")
matches = re.sub(r"[А-Я]",'_', data)
print(matches)
# Out:
# task 10
# ________
# абб
# фпбб
# вчпыаббб
# абрикос
# аббболла
# ббааллааб
# _илиал ___ EUROPHARMA _стана
# ___ 080841000761
# ___ _ерия 58001
#  № 0014377
# _асса 300-189
# _мена 10
# _орядковый номер чека №64
# _ек №2331180266
# _ассир _птека 17-1
# _______
# 1.
# _атрия хлорид 0,9%, 200 мл, фл
# 2,000 x 154,00
# 308,00
# _тоимость
# 308,00
# 2.
# _орный спирт 3%, 20 мл, фл.
# 1,000 x 51,00
# 51,00
# _тоимость
# 51,00
# 3.
# _приц 2 мл, 3-х комп. (Bioject)
# 2,000 x 16,00
# 32,00
# _тоимость
# 32,00
# 4.
# _истема для инфузии Vogt Medical
# 2,000 x 60,00
# 120,00
# _тоимость
# 120,00
# 5.
# Naturella прокладки _лассик макси №8
# 1,000 x 310,00
# 310,00
# _тоимость
# 310,00
# 6.
# AURA _атные диски №150
# 1,000 x 461,00
# 461,00
# _тоимость
# 461,00
# 7.
# _истая линия скраб мягкий 50 мл
# 1,000 x 381,00
# 381,00
# _тоимость
# 381,00
# 8.
# _истая линия  скраб очищающийабрикос 50 мл
# 1,000 x 386,00
# 386,00
# _тоимость
# 386,00
# 9.
# _истая линия скраб мягкий 50 мл
# 1,000 x 381,00
# 381,00
# _тоимость
# 381,00
# 10.
# Carefree салфетки _лоэвоздухопроницаемые №20
# 1,000 x 414,00
# 414,00
# _тоимость
# 414,00
# 11.
# Pro Series _ампунь яркий цвет 500мл
# 1,000 x 841,00
# 841,00
# _тоимость
# 841,00
# 12.
# Pro Series бальзам-ополаскивательдля длител ухода за окрашеннымиволосами _ркий цвет 500мл
# 1,000 x 841,00
# 841,00
# _тоимость
# 841,00
# 13.
# Clear шампунь _ктив спорт 2в1мужской  400 мл
# 1,000 x 1 200,00
# 1 200,00
# _тоимость
# 1 200,00
# 14.
# Bio World (HYDRO THERAPY)_ицеллярная вода 5в1, 445мл
# 1,000 x 1 152,00
# 1 152,00
# _тоимость
# 1 152,00
# 15.
# Bio World (HYDRO THERAPY) _ель-муссдля умывания с гиалуроновойкислотой, 250мл
# 1,000 x 1 152,00
# 1 152,00
# _тоимость
# 1 152,00
# 16.
# [RX]-_атрия хлорид 0,9%, 100 мл, фл.
# 1,000 x 168,00
# 168,00
# _тоимость
# 168,00
# 17.
# [RX]-_исоль р-р 400 мл, фл.
# 1,000 x 163,00
# 163,00
# _тоимость
# 163,00
# 18.
# _агансорбент с иономи серебра №30,пор.
# 1,000 x 1 526,00
# 1 526,00
# _тоимость
# 1 526,00
# 19.
# [RX]-_ерукал 2%, 2 мл, №10, амп.
# 2,000 x 396,00
# 792,00
# _тоимость
# 792,00
# 20.
# [RX]-_ндазол 200 мг, №40, табл.
# 1,000 x 7 330,00
# 7 330,00
# _тоимость
# 7 330,00
# _анковская карта:
# 18 009,00
# _____:
# 18 009,00
# в т.ч. ___ 12%:
# 0,00
# _искальный признак:
# 2331180266
# _ремя: 18.04.2019 11:13:58
# г. _ур-султан,_азахстан, _ангилик _л,19, нп-5
# _ператор фискальных данных: __"_азахтелеком"_ля проверки чека зайдите на сайт:consumer.oofd.kz
# __________ ___
# __
# ___ ___: 311559
# _од ___ ___ (___): 620300145316
# ___: SWK00034961
# WEBKASSA.KZ
